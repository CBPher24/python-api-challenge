# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
#import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint
from scipy.stats import linregress
from datetime import date

# Import API key
#api_keys = os.path.relpath(r"../Resources/api_keys.py")
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="https://nominatim.openstreetmap.org")

# Output File (CSV)
output_data_file = "output_data/cities.csv"

#Todays date variable
today = date.today()

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)


# # Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# # Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %%
# #code to use a geopy loop to produce cities just to get started
# keys = ["village","town", "city_district", "city", "suburb"]
# for lat,lng in lat_lngs:
#     if len(cities) == 500:
#         break
#     location = geolocator.reverse(f"{lat},{lng}", language="en-US", timeout=None)  
#     if location != None:
#         addr = location.raw["address"]
#         #pprint.pprint(addr)
#         for key in keys:
#             #print(key)
#             if key in addr:
#                 #print(key)
#                 city = addr[key]
#                 #print(city)
#                 if city not in cities:
#                     cities.append(city)
#                 break

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#print(cities)
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

dict_keys = ["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]
weather = {}
City_ID = 0

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

counter = 0
# #loop to query cities
for place in cities:
    try:
        output = requests.get(query_url + place).json()
        print(f"Success: Progress {counter} of {len(cities)-1} | {City_ID},{output['name']}")
        city_pull = {"City": (output["name"]),
                 "Cloudiness": (output["clouds"]["all"]),
                 "Country": (output["sys"]["country"]),
                 "Date": (output["dt"]),
                 "Humidity": (output["main"]["humidity"]),
                 "Lat": (output["coord"]["lat"]),
                 "Lng": (output["coord"]["lon"]),
                 "Max Temp": (output["main"]["temp_max"]),
                 "Wind Speed": (output["wind"]["speed"])}
        weather[City_ID] = city_pull
        City_ID += 1
    except:
        print(f"Fail: Progress {counter} of {len(cities)}")
    counter += 1
# Out:
# Success: Progress 0 of 624 | 0,Ushuaia
# Success: Progress 1 of 624 | 1,San Patricio
# Success: Progress 2 of 624 | 2,Butaritari
# Success: Progress 3 of 624 | 3,Abu Samrah
# Success: Progress 4 of 624 | 4,Busselton
# Success: Progress 5 of 624 | 5,Thompson
# Success: Progress 6 of 624 | 6,Zhongshu
# Success: Progress 7 of 624 | 7,Rikitea
# Success: Progress 8 of 624 | 8,Vardø
# Success: Progress 9 of 624 | 9,Tutóia
# Success: Progress 10 of 624 | 10,Isiro
# Success: Progress 11 of 624 | 11,Punta Arenas
# Success: Progress 12 of 624 | 12,Lagoa
# Fail: Progress 13 of 625
# Success: Progress 14 of 624 | 13,Arraial do Cabo
# Success: Progress 15 of 624 | 14,Simao
# Success: Progress 16 of 624 | 15,Nikolskoye
# Success: Progress 17 of 624 | 16,Saldanha
# Success: Progress 18 of 624 | 17,George Town
# Success: Progress 19 of 624 | 18,New Norfolk
# Success: Progress 20 of 624 | 19,Hobart
# Success: Progress 21 of 624 | 20,Carnarvon
# Success: Progress 22 of 624 | 21,Castro
# Success: Progress 23 of 624 | 22,Hilo
# Success: Progress 24 of 624 | 23,Bredasdorp
# Fail: Progress 25 of 625
# Success: Progress 26 of 624 | 24,Lompoc
# Success: Progress 27 of 624 | 25,Forbesganj
# Success: Progress 28 of 624 | 26,Souillac
# Success: Progress 29 of 624 | 27,Albany
# Success: Progress 30 of 624 | 28,Baykit
# Success: Progress 31 of 624 | 29,Hithadhoo
# Success: Progress 32 of 624 | 30,Ixtapa
# Success: Progress 33 of 624 | 31,Jamestown
# Success: Progress 34 of 624 | 32,Tsumeb
# Success: Progress 35 of 624 | 33,Soyo
# Success: Progress 36 of 624 | 34,Chemax
# Success: Progress 37 of 624 | 35,Atuona
# Success: Progress 38 of 624 | 36,Tasiilaq
# Fail: Progress 39 of 625
# Success: Progress 40 of 624 | 37,Narsaq
# Success: Progress 41 of 624 | 38,Saint Paul Harbor
# Success: Progress 42 of 624 | 39,Mataura
# Fail: Progress 43 of 625
# Success: Progress 44 of 624 | 40,Khovd
# Success: Progress 45 of 624 | 41,Gurupá
# Success: Progress 46 of 624 | 42,Lebu
# Success: Progress 47 of 624 | 43,Bluff
# Success: Progress 48 of 624 | 44,Qaanaaq
# Fail: Progress 49 of 625
# Success: Progress 50 of 624 | 45,Sault Ste. Marie
# Success: Progress 51 of 624 | 46,Salalah
# Success: Progress 52 of 624 | 47,Barrow
# Success: Progress 53 of 624 | 48,East London
# Success: Progress 54 of 624 | 49,Sittwe
# Success: Progress 55 of 624 | 50,Nome
# Success: Progress 56 of 624 | 51,Lircay
# Success: Progress 57 of 624 | 52,La Ronge
# Success: Progress 58 of 624 | 53,Abalak
# Success: Progress 59 of 624 | 54,Plátanos
# Success: Progress 60 of 624 | 55,Naze
# Success: Progress 61 of 624 | 56,Östersund
# Success: Progress 62 of 624 | 57,Pedro Carbo
# Success: Progress 63 of 624 | 58,Bilibino
# Success: Progress 64 of 624 | 59,Ribeira Grande
# Success: Progress 65 of 624 | 60,Ocós
# Success: Progress 66 of 624 | 61,Navashino
# Success: Progress 67 of 624 | 62,Sosnovo-Ozerskoye
# Success: Progress 68 of 624 | 63,Cabo San Lucas
# Fail: Progress 69 of 625
# Success: Progress 70 of 624 | 64,Yellowknife
# Fail: Progress 71 of 625
# Success: Progress 72 of 624 | 65,Cape Town
# Success: Progress 73 of 624 | 66,Mossamedes
# Success: Progress 74 of 624 | 67,Yar-Sale
# Success: Progress 75 of 624 | 68,Cayenne
# Success: Progress 76 of 624 | 69,Chaiya
# Success: Progress 77 of 624 | 70,Atasū
# Success: Progress 78 of 624 | 71,Hermanus
# Success: Progress 79 of 624 | 72,Jiehu
# Success: Progress 80 of 624 | 73,Borba
# Success: Progress 81 of 624 | 74,Puerto Ayora
# Fail: Progress 82 of 625
# Success: Progress 83 of 624 | 75,Katsuura
# Success: Progress 84 of 624 | 76,Krutinka
# Success: Progress 85 of 624 | 77,Mar del Plata
# Success: Progress 86 of 624 | 78,Kavieng
# Success: Progress 87 of 624 | 79,Khasan
# Success: Progress 88 of 624 | 80,Santa Helena
# Success: Progress 89 of 624 | 81,Severo-Kuril'sk
# Success: Progress 90 of 624 | 82,Puerto Ayacucho
# Success: Progress 91 of 624 | 83,Hihyā
# Success: Progress 92 of 624 | 84,Banda Aceh
# Success: Progress 93 of 624 | 85,Khatanga
# Success: Progress 94 of 624 | 86,Guerrero Negro
# Fail: Progress 95 of 625
# Success: Progress 96 of 624 | 87,Tuktoyaktuk
# Success: Progress 97 of 624 | 88,Vaini
# Success: Progress 98 of 624 | 89,Kita
# Fail: Progress 99 of 625
# Fail: Progress 100 of 625
# Success: Progress 101 of 624 | 90,Saint-Michel-des-Saints
# Success: Progress 102 of 624 | 91,Arkhangelsk
# Success: Progress 103 of 624 | 92,Cidreira
# Success: Progress 104 of 624 | 93,Longyearbyen
# Success: Progress 105 of 624 | 94,Isangel
# Success: Progress 106 of 624 | 95,Cherëmukhovo
# Success: Progress 107 of 624 | 96,Ponta do Sol
# Success: Progress 108 of 624 | 97,Bonthe
# Success: Progress 109 of 624 | 98,Salinas
# Success: Progress 110 of 624 | 99,São José da Coroa Grande
# Success: Progress 111 of 624 | 100,Sitka
# Success: Progress 112 of 624 | 101,Lubao
# Success: Progress 113 of 624 | 102,Hangha
# Success: Progress 114 of 624 | 103,Necochea
# Success: Progress 115 of 624 | 104,Port Elizabeth
# Success: Progress 116 of 624 | 105,Ucluelet
# Success: Progress 117 of 624 | 106,Dikson
# Success: Progress 118 of 624 | 107,Champerico
# Success: Progress 119 of 624 | 108,Hong Kong
# Fail: Progress 120 of 625
# Success: Progress 121 of 624 | 109,Broome
# Fail: Progress 122 of 625
# Fail: Progress 123 of 625
# Success: Progress 124 of 624 | 110,Poya
# Success: Progress 125 of 624 | 111,Zhezkazgan
# Success: Progress 126 of 624 | 112,Itupiranga
# Success: Progress 127 of 624 | 113,Paamiut
# Success: Progress 128 of 624 | 114,Altay
# Success: Progress 129 of 624 | 115,Jaru
# Success: Progress 130 of 624 | 116,Djibo
# Success: Progress 131 of 624 | 117,Kibaya
# Success: Progress 132 of 624 | 118,Kapaa
# Success: Progress 133 of 624 | 119,Charlottetown
# Success: Progress 134 of 624 | 120,Okha
# Success: Progress 135 of 624 | 121,Dauriya
# Fail: Progress 136 of 625
# Success: Progress 137 of 624 | 122,Yaan
# Success: Progress 138 of 624 | 123,General Roca
# Success: Progress 139 of 624 | 124,Aykhal
# Fail: Progress 140 of 625
# Success: Progress 141 of 624 | 125,Ossora
# Success: Progress 142 of 624 | 126,Nhulunbuy
# Success: Progress 143 of 624 | 127,Bilma
# Fail: Progress 144 of 625
# Success: Progress 145 of 624 | 128,Son La
# Success: Progress 146 of 624 | 129,Havøysund
# Success: Progress 147 of 624 | 130,Berea
# Success: Progress 148 of 624 | 131,Provideniya
# Success: Progress 149 of 624 | 132,Miles City
# Success: Progress 150 of 624 | 133,Vilyuysk
# Success: Progress 151 of 624 | 134,Lata
# Success: Progress 152 of 624 | 135,Kalevala
# Success: Progress 153 of 624 | 136,Klaksvík
# Success: Progress 154 of 624 | 137,Caohai
# Success: Progress 155 of 624 | 138,Esperance
# Success: Progress 156 of 624 | 139,Ketchikan
# Success: Progress 157 of 624 | 140,Teeli
# Success: Progress 158 of 624 | 141,Kalmunai
# Fail: Progress 159 of 625
# Success: Progress 160 of 624 | 142,Padang
# Success: Progress 161 of 624 | 143,Sinnai
# Success: Progress 162 of 624 | 144,Hamilton
# Success: Progress 163 of 624 | 145,Tawang Town
# Success: Progress 164 of 624 | 146,Ilulissat
# Success: Progress 165 of 624 | 147,Upernavik
# Success: Progress 166 of 624 | 148,Torbay
# Success: Progress 167 of 624 | 149,Bengkulu
# Success: Progress 168 of 624 | 150,Grand Gaube
# Success: Progress 169 of 624 | 151,Jacareacanga
# Success: Progress 170 of 624 | 152,Chui
# Success: Progress 171 of 624 | 153,Goundam
# Success: Progress 172 of 624 | 154,Saint-Philippe
# Fail: Progress 173 of 625
# Success: Progress 174 of 624 | 155,Los Llanos de Aridane
# Success: Progress 175 of 624 | 156,Nioro
# Success: Progress 176 of 624 | 157,Ofakim
# Success: Progress 177 of 624 | 158,Viedma
# Success: Progress 178 of 624 | 159,Dolores
# Success: Progress 179 of 624 | 160,Nouadhibou
# Success: Progress 180 of 624 | 161,Olafsvik
# Success: Progress 181 of 624 | 162,Haapiti
# Success: Progress 182 of 624 | 163,Ancud
# Success: Progress 183 of 624 | 164,Port Hedland
# Success: Progress 184 of 624 | 165,Tamworth
# Success: Progress 185 of 624 | 166,Saint George
# Success: Progress 186 of 624 | 167,Fianarantsoa
# Success: Progress 187 of 624 | 168,Gijón
# Fail: Progress 188 of 625
# Success: Progress 189 of 624 | 169,Sinnamary
# Success: Progress 190 of 624 | 170,São João da Barra
# Success: Progress 191 of 624 | 171,Praxédis Guerrero
# Success: Progress 192 of 624 | 172,Athabasca
# Success: Progress 193 of 624 | 173,Stokmarknes
# Success: Progress 194 of 624 | 174,Tampin
# Success: Progress 195 of 624 | 175,Talnakh
# Success: Progress 196 of 624 | 176,Lüderitz
# Fail: Progress 197 of 625
# Success: Progress 198 of 624 | 177,Tougue
# Success: Progress 199 of 624 | 178,Rafai
# Success: Progress 200 of 624 | 179,Osa
# Success: Progress 201 of 624 | 180,Nyimba
# Success: Progress 202 of 624 | 181,Mountain Home
# Fail: Progress 203 of 625
# Success: Progress 204 of 624 | 182,Manbij
# Success: Progress 205 of 624 | 183,Chokurdakh
# Success: Progress 206 of 624 | 184,Quimper
# Success: Progress 207 of 624 | 185,Yabrūd
# Success: Progress 208 of 624 | 186,Doboj
# Success: Progress 209 of 624 | 187,Bethel
# Success: Progress 210 of 624 | 188,Dzhebariki-Khaya
# Fail: Progress 211 of 625
# Success: Progress 212 of 624 | 189,Kavaratti
# Success: Progress 213 of 624 | 190,Kharan
# Success: Progress 214 of 624 | 191,Portland
# Success: Progress 215 of 624 | 192,Bambous Virieux
# Success: Progress 216 of 624 | 193,Egvekinot
# Success: Progress 217 of 624 | 194,São Filipe
# Success: Progress 218 of 624 | 195,Bathsheba
# Success: Progress 219 of 624 | 196,Ulladulla
# Success: Progress 220 of 624 | 197,Waingapu
# Success: Progress 221 of 624 | 198,Kruisfontein
# Success: Progress 222 of 624 | 199,Bereda
# Success: Progress 223 of 624 | 200,La Palma
# Success: Progress 224 of 624 | 201,Verāval
# Success: Progress 225 of 624 | 202,Maţāy
# Success: Progress 226 of 624 | 203,Walvis Bay
# Fail: Progress 227 of 625
# Success: Progress 228 of 624 | 204,Huarmey
# Success: Progress 229 of 624 | 205,Winnemucca
# Success: Progress 230 of 624 | 206,Mt. Pleasant
# Success: Progress 231 of 624 | 207,Eilat
# Success: Progress 232 of 624 | 208,Muzhi
# Success: Progress 233 of 624 | 209,Tigil'
# Success: Progress 234 of 624 | 210,Lorengau
# Success: Progress 235 of 624 | 211,Port Alfred
# Fail: Progress 236 of 625
# Fail: Progress 237 of 625
# Success: Progress 238 of 624 | 212,Formiga
# Success: Progress 239 of 624 | 213,Rio Pardo
# Success: Progress 240 of 624 | 214,Beringovskiy
# Fail: Progress 241 of 625
# Success: Progress 242 of 624 | 215,Barabai
# Success: Progress 243 of 624 | 216,Ajdabiya
# Success: Progress 244 of 624 | 217,Gorontalo
# Success: Progress 245 of 624 | 218,Sheridan
# Fail: Progress 246 of 625
# Fail: Progress 247 of 625
# Success: Progress 248 of 624 | 219,Bukama
# Success: Progress 249 of 624 | 220,El Salvador
# Success: Progress 250 of 624 | 221,Finschhafen
# Success: Progress 251 of 624 | 222,Inhambane
# Success: Progress 252 of 624 | 223,Taltal
# Success: Progress 253 of 624 | 224,Papara
# Success: Progress 254 of 624 | 225,Ambulu
# Success: Progress 255 of 624 | 226,Caravelas
# Fail: Progress 256 of 625
# Fail: Progress 257 of 625
# Success: Progress 258 of 624 | 227,Flagstaff
# Success: Progress 259 of 624 | 228,Norman Wells
# Success: Progress 260 of 624 | 229,Kungurtug
# Success: Progress 261 of 624 | 230,Manta
# Success: Progress 262 of 624 | 231,Hobyo
# Success: Progress 263 of 624 | 232,Udachny
# Success: Progress 264 of 624 | 233,Tiksi
# Success: Progress 265 of 624 | 234,Berlevåg
# Success: Progress 266 of 624 | 235,Laguna
# Success: Progress 267 of 624 | 236,Ust'-Barguzin
# Success: Progress 268 of 624 | 237,Camacha
# Success: Progress 269 of 624 | 238,Avarua
# Success: Progress 270 of 624 | 239,Saskylakh
# Success: Progress 271 of 624 | 240,Pierre
# Success: Progress 272 of 624 | 241,Isla Mujeres
# Success: Progress 273 of 624 | 242,Khrebtovaya
# Fail: Progress 274 of 625
# Success: Progress 275 of 624 | 243,Byron Bay
# Success: Progress 276 of 624 | 244,Sibu
# Success: Progress 277 of 624 | 245,Hohhot
# Success: Progress 278 of 624 | 246,Codrington
# Fail: Progress 279 of 625
# Success: Progress 280 of 624 | 247,San Quintín
# Success: Progress 281 of 624 | 248,Gornje Živinice
# Success: Progress 282 of 624 | 249,Metro
# Success: Progress 283 of 624 | 250,Atar
# Success: Progress 284 of 624 | 251,Hambantota
# Fail: Progress 285 of 625
# Success: Progress 286 of 624 | 252,Gwembe
# Success: Progress 287 of 624 | 253,Gao
# Success: Progress 288 of 624 | 254,Jiuquan
# Fail: Progress 289 of 625
# Success: Progress 290 of 624 | 255,Verkhnyaya Inta
# Success: Progress 291 of 624 | 256,Mogadishu
# Success: Progress 292 of 624 | 257,Rochegda
# Success: Progress 293 of 624 | 258,Lavrentiya
# Success: Progress 294 of 624 | 259,Puerto Concordia
# Success: Progress 295 of 624 | 260,Mareeba
# Success: Progress 296 of 624 | 261,Kumluca
# Success: Progress 297 of 624 | 262,Izhma
# Success: Progress 298 of 624 | 263,Bafra
# Success: Progress 299 of 624 | 264,Lázaro Cárdenas
# Success: Progress 300 of 624 | 265,Kirishi
# Success: Progress 301 of 624 | 266,Oranjemund
# Success: Progress 302 of 624 | 267,Troutdale
# Success: Progress 303 of 624 | 268,Burns Lake
# Success: Progress 304 of 624 | 269,Naivasha
# Success: Progress 305 of 624 | 270,New Ipswich
# Success: Progress 306 of 624 | 271,Praia
# Success: Progress 307 of 624 | 272,Wyszków
# Success: Progress 308 of 624 | 273,Iqaluit
# Success: Progress 309 of 624 | 274,Sheregesh
# Success: Progress 310 of 624 | 275,Talakan
# Success: Progress 311 of 624 | 276,Cairns
# Success: Progress 312 of 624 | 277,Ostrovnoy
# Success: Progress 313 of 624 | 278,Tonneins
# Success: Progress 314 of 624 | 279,Robertsport
# Fail: Progress 315 of 625
# Success: Progress 316 of 624 | 280,Kaitangata
# Success: Progress 317 of 624 | 281,Chute-aux-Outardes
# Success: Progress 318 of 624 | 282,Kilakarai
# Success: Progress 319 of 624 | 283,Margate
# Success: Progress 320 of 624 | 284,Clyde River
# Success: Progress 321 of 624 | 285,Asău
# Success: Progress 322 of 624 | 286,Aksarka
# Success: Progress 323 of 624 | 287,Waipawa
# Success: Progress 324 of 624 | 288,Aswān
# Success: Progress 325 of 624 | 289,Shache
# Success: Progress 326 of 624 | 290,Hofn
# Success: Progress 327 of 624 | 291,Mahébourg
# Success: Progress 328 of 624 | 292,Yelizovo
# Success: Progress 329 of 624 | 293,Casino
# Success: Progress 330 of 624 | 294,Surgut
# Success: Progress 331 of 624 | 295,Tommot
# Success: Progress 332 of 624 | 296,Lashio
# Success: Progress 333 of 624 | 297,Tuatapere
# Fail: Progress 334 of 625
# Success: Progress 335 of 624 | 298,Ambilobe
# Success: Progress 336 of 624 | 299,Jalu
# Success: Progress 337 of 624 | 300,Te Anau
# Success: Progress 338 of 624 | 301,Geraldton
# Success: Progress 339 of 624 | 302,Pemangkat
# Success: Progress 340 of 624 | 303,Airai
# Success: Progress 341 of 624 | 304,Rovaniemi
# Success: Progress 342 of 624 | 305,Panguna
# Success: Progress 343 of 624 | 306,Tual
# Success: Progress 344 of 624 | 307,Barra de Tecoanapa
# Success: Progress 345 of 624 | 308,Noumea
# Success: Progress 346 of 624 | 309,Tirano
# Success: Progress 347 of 624 | 310,Rapid City
# Success: Progress 348 of 624 | 311,Iquique
# Success: Progress 349 of 624 | 312,Birjand
# Success: Progress 350 of 624 | 313,San Policarpo
# Success: Progress 351 of 624 | 314,Nikolayevsk-on-Amur
# Success: Progress 352 of 624 | 315,Lake Charles
# Success: Progress 353 of 624 | 316,Lorain
# Success: Progress 354 of 624 | 317,Vila Franca do Campo
# Success: Progress 355 of 624 | 318,Roald
# Success: Progress 356 of 624 | 319,San Juan
# Success: Progress 357 of 624 | 320,Laichow
# Success: Progress 358 of 624 | 321,Sobolevo
# Success: Progress 359 of 624 | 322,Māngrol
# Success: Progress 360 of 624 | 323,Batamshinskiy
# Success: Progress 361 of 624 | 324,Topi
# Success: Progress 362 of 624 | 325,Hasaki
# Success: Progress 363 of 624 | 326,Hūn
# Success: Progress 364 of 624 | 327,Samaná
# Success: Progress 365 of 624 | 328,Boende
# Success: Progress 366 of 624 | 329,Challans
# Fail: Progress 367 of 625
# Success: Progress 368 of 624 | 330,Kahului
# Success: Progress 369 of 624 | 331,Sokoni
# Success: Progress 370 of 624 | 332,Luanda
# Success: Progress 371 of 624 | 333,Cavalcante
# Success: Progress 372 of 624 | 334,Phang Nga
# Success: Progress 373 of 624 | 335,Gongzhuling
# Success: Progress 374 of 624 | 336,Korla
# Success: Progress 375 of 624 | 337,Pevek
# Success: Progress 376 of 624 | 338,Middletown
# Success: Progress 377 of 624 | 339,Rondonópolis
# Success: Progress 378 of 624 | 340,Arrondissement de Cognac
# Success: Progress 379 of 624 | 341,Coyhaique
# Success: Progress 380 of 624 | 342,Tautira
# Success: Progress 381 of 624 | 343,Boa Vista
# Fail: Progress 382 of 625
# Success: Progress 383 of 624 | 344,Bemidji
# Success: Progress 384 of 624 | 345,Morgan City
# Success: Progress 385 of 624 | 346,Yulara
# Success: Progress 386 of 624 | 347,Ordzhonīkīdze
# Success: Progress 387 of 624 | 348,Nautla
# Success: Progress 388 of 624 | 349,Nelson Bay
# Success: Progress 389 of 624 | 350,Manokwari
# Success: Progress 390 of 624 | 351,Fortuna
# Success: Progress 391 of 624 | 352,Centralia
# Success: Progress 392 of 624 | 353,Wichita Falls
# Success: Progress 393 of 624 | 354,Amarpur
# Success: Progress 394 of 624 | 355,Kindersley
# Success: Progress 395 of 624 | 356,Zhangaözen
# Success: Progress 396 of 624 | 357,Vila Velha
# Success: Progress 397 of 624 | 358,Westport
# Success: Progress 398 of 624 | 359,Aksu
# Success: Progress 399 of 624 | 360,Marsh Harbour
# Success: Progress 400 of 624 | 361,Mount Isa
# Success: Progress 401 of 624 | 362,Fare
# Success: Progress 402 of 624 | 363,Kafue
# Fail: Progress 403 of 625
# Success: Progress 404 of 624 | 364,Vostok
# Fail: Progress 405 of 625
# Success: Progress 406 of 624 | 365,Keetmanshoop
# Success: Progress 407 of 624 | 366,Nakatsugawa
# Success: Progress 408 of 624 | 367,Chapais
# Success: Progress 409 of 624 | 368,Marawi
# Success: Progress 410 of 624 | 369,Laas
# Fail: Progress 411 of 625
# Success: Progress 412 of 624 | 370,Daru
# Success: Progress 413 of 624 | 371,Sémbé
# Success: Progress 414 of 624 | 372,Wanning
# Success: Progress 415 of 624 | 373,Japura
# Success: Progress 416 of 624 | 374,Tanout
# Success: Progress 417 of 624 | 375,São Tomé
# Success: Progress 418 of 624 | 376,Nishihara
# Success: Progress 419 of 624 | 377,Lerwick
# Success: Progress 420 of 624 | 378,Shirvan
# Success: Progress 421 of 624 | 379,Termoli
# Success: Progress 422 of 624 | 380,Miguel Calmon
# Success: Progress 423 of 624 | 381,Gunjur
# Success: Progress 424 of 624 | 382,Pacific Grove
# Fail: Progress 425 of 625
# Success: Progress 426 of 624 | 383,Mbanza-Ngungu
# Success: Progress 427 of 624 | 384,Atherton
# Success: Progress 428 of 624 | 385,Touros
# Success: Progress 429 of 624 | 386,Koslan
# Success: Progress 430 of 624 | 387,Constitución
# Success: Progress 431 of 624 | 388,Dhārchula
# Success: Progress 432 of 624 | 389,Strezhevoy
# Success: Progress 433 of 624 | 390,Kjøpsvik
# Success: Progress 434 of 624 | 391,Balkanabat
# Success: Progress 435 of 624 | 392,Clarence Town
# Success: Progress 436 of 624 | 393,Oulu
# Success: Progress 437 of 624 | 394,São João do Paraíso
# Success: Progress 438 of 624 | 395,Richards Bay
# Success: Progress 439 of 624 | 396,Haines Junction
# Success: Progress 440 of 624 | 397,Kumul
# Success: Progress 441 of 624 | 398,Maun
# Success: Progress 442 of 624 | 399,Calabozo
# Success: Progress 443 of 624 | 400,Zhuhai
# Success: Progress 444 of 624 | 401,Enterprise
# Success: Progress 445 of 624 | 402,Itarema
# Fail: Progress 446 of 625
# Success: Progress 447 of 624 | 403,Pemba
# Success: Progress 448 of 624 | 404,Zandvoort
# Success: Progress 449 of 624 | 405,Kuytun
# Success: Progress 450 of 624 | 406,Awjilah
# Success: Progress 451 of 624 | 407,Itoman
# Fail: Progress 452 of 625
# Success: Progress 453 of 624 | 408,Zonguldak
# Success: Progress 454 of 624 | 409,Mabaruma
# Success: Progress 455 of 624 | 410,Mount Gambier
# Success: Progress 456 of 624 | 411,Mezen'
# Success: Progress 457 of 624 | 412,Maceió
# Success: Progress 458 of 624 | 413,Ukiah
# Success: Progress 459 of 624 | 414,Foumbot
# Success: Progress 460 of 624 | 415,Onda
# Success: Progress 461 of 624 | 416,Pandan
# Success: Progress 462 of 624 | 417,Were Īlu
# Success: Progress 463 of 624 | 418,Barentu
# Fail: Progress 464 of 625
# Success: Progress 465 of 624 | 419,Beroroha
# Success: Progress 466 of 624 | 420,Porbandar
# Fail: Progress 467 of 625
# Success: Progress 468 of 624 | 421,Caçu
# Success: Progress 469 of 624 | 422,Ola
# Success: Progress 470 of 624 | 423,Springbok
# Success: Progress 471 of 624 | 424,Tezu
# Fail: Progress 472 of 625
# Success: Progress 473 of 624 | 425,Olinda
# Success: Progress 474 of 624 | 426,Kupang
# Success: Progress 475 of 624 | 427,Gamba
# Success: Progress 476 of 624 | 428,Témiscaming
# Success: Progress 477 of 624 | 429,Wuda
# Success: Progress 478 of 624 | 430,North Myrtle Beach
# Success: Progress 479 of 624 | 431,Raudeberg
# Success: Progress 480 of 624 | 432,Palana
# Success: Progress 481 of 624 | 433,Buckeye
# Success: Progress 482 of 624 | 434,Pacasmayo
# Success: Progress 483 of 624 | 435,Kargasok
# Success: Progress 484 of 624 | 436,Prainha
# Success: Progress 485 of 624 | 437,Massa Marittima
# Success: Progress 486 of 624 | 438,Chulym
# Success: Progress 487 of 624 | 439,Porto-Novo
# Success: Progress 488 of 624 | 440,Selma
# Success: Progress 489 of 624 | 441,Riyadh
# Success: Progress 490 of 624 | 442,Şabyā
# Success: Progress 491 of 624 | 443,Saint-Césaire
# Success: Progress 492 of 624 | 444,Mahon
# Success: Progress 493 of 624 | 445,Assiut
# Success: Progress 494 of 624 | 446,Umluj
# Success: Progress 495 of 624 | 447,Dombarovskiy
# Success: Progress 496 of 624 | 448,Ahipara
# Success: Progress 497 of 624 | 449,Mehamn
# Success: Progress 498 of 624 | 450,Anloga
# Success: Progress 499 of 624 | 451,Chul'man
# Fail: Progress 500 of 625
# Success: Progress 501 of 624 | 452,Yasothon
# Success: Progress 502 of 624 | 453,Camapuã
# Success: Progress 503 of 624 | 454,Morondava
# Success: Progress 504 of 624 | 455,Leningradskiy
# Success: Progress 505 of 624 | 456,Tura
# Success: Progress 506 of 624 | 457,Cândido de Abreu
# Success: Progress 507 of 624 | 458,Puqi
# Success: Progress 508 of 624 | 459,Diego de Almagro
# Success: Progress 509 of 624 | 460,Najrān
# Success: Progress 510 of 624 | 461,Esso
# Success: Progress 511 of 624 | 462,Las Tunas
# Success: Progress 512 of 624 | 463,Cherskiy
# Success: Progress 513 of 624 | 464,Faanui
# Success: Progress 514 of 624 | 465,Diamantino
# Success: Progress 515 of 624 | 466,Ambon City
# Success: Progress 516 of 624 | 467,Partenit
# Success: Progress 517 of 624 | 468,Jumla
# Success: Progress 518 of 624 | 469,Shimoda
# Success: Progress 519 of 624 | 470,Gilbués
# Success: Progress 520 of 624 | 471,Zarand
# Success: Progress 521 of 624 | 472,Oppdal
# Success: Progress 522 of 624 | 473,Arlit
# Success: Progress 523 of 624 | 474,Coquimbo
# Success: Progress 524 of 624 | 475,Staroutkinsk
# Success: Progress 525 of 624 | 476,Qaqortoq
# Success: Progress 526 of 624 | 477,Rawson
# Success: Progress 527 of 624 | 478,Ishigaki
# Success: Progress 528 of 624 | 479,Glencoe
# Success: Progress 529 of 624 | 480,Morros
# Success: Progress 530 of 624 | 481,Bagdarin
# Success: Progress 531 of 624 | 482,Jaguaruna
# Success: Progress 532 of 624 | 483,Coahuayana Viejo
# Success: Progress 533 of 624 | 484,Seoul
# Success: Progress 534 of 624 | 485,Juba
# Success: Progress 535 of 624 | 486,Arman'
# Success: Progress 536 of 624 | 487,San Andrés
# Fail: Progress 537 of 625
# Success: Progress 538 of 624 | 488,Palmer
# Success: Progress 539 of 624 | 489,Kaili
# Success: Progress 540 of 624 | 490,Alofi
# Success: Progress 541 of 624 | 491,Labuhan
# Success: Progress 542 of 624 | 492,Kainantu
# Fail: Progress 543 of 625
# Success: Progress 544 of 624 | 493,Caesarea
# Success: Progress 545 of 624 | 494,Tsimlyansk
# Success: Progress 546 of 624 | 495,Betong
# Success: Progress 547 of 624 | 496,Grindavik
# Success: Progress 548 of 624 | 497,Ballina
# Success: Progress 549 of 624 | 498,Merauke
# Success: Progress 550 of 624 | 499,Topaowan
# Success: Progress 551 of 624 | 500,Río Gallegos
# Success: Progress 552 of 624 | 501,Meulaboh
# Success: Progress 553 of 624 | 502,Poltavka
# Success: Progress 554 of 624 | 503,Tuy Hoa
# Success: Progress 555 of 624 | 504,Patacamaya
# Success: Progress 556 of 624 | 505,Adwa
# Success: Progress 557 of 624 | 506,Cedar City
# Success: Progress 558 of 624 | 507,São Paulo de Olivença
# Success: Progress 559 of 624 | 508,Līsakovsk
# Fail: Progress 560 of 625
# Success: Progress 561 of 624 | 509,Ingham
# Success: Progress 562 of 624 | 510,Pingliang
# Success: Progress 563 of 624 | 511,Buraidah
# Success: Progress 564 of 624 | 512,Acaraú
# Success: Progress 565 of 624 | 513,Iquitos
# Success: Progress 566 of 624 | 514,Whitehorse
# Success: Progress 567 of 624 | 515,Ponta Delgada
# Success: Progress 568 of 624 | 516,Kismayo
# Success: Progress 569 of 624 | 517,Sirte
# Success: Progress 570 of 624 | 518,Luan
# Success: Progress 571 of 624 | 519,San Jose
# Success: Progress 572 of 624 | 520,North Bend
# Success: Progress 573 of 624 | 521,Monrovia
# Success: Progress 574 of 624 | 522,Fiumicino
# Success: Progress 575 of 624 | 523,Unión de Reyes
# Success: Progress 576 of 624 | 524,Flinders
# Success: Progress 577 of 624 | 525,Port Augusta
# Success: Progress 578 of 624 | 526,Anadyr
# Fail: Progress 579 of 625
# Success: Progress 580 of 624 | 527,Saint Anthony
# Success: Progress 581 of 624 | 528,Henties Bay
# Success: Progress 582 of 624 | 529,Northam
# Success: Progress 583 of 624 | 530,Örnsköldsvik
# Fail: Progress 584 of 625
# Success: Progress 585 of 624 | 531,St. George's
# Success: Progress 586 of 624 | 532,Wanaka
# Success: Progress 587 of 624 | 533,Paso de Carrasco
# Success: Progress 588 of 624 | 534,Talara
# Success: Progress 589 of 624 | 535,Sakakah
# Success: Progress 590 of 624 | 536,Lakatoro
# Success: Progress 591 of 624 | 537,Reyes
# Success: Progress 592 of 624 | 538,Rio Verde de Mato Grosso
# Success: Progress 593 of 624 | 539,Bhadrāchalam
# Success: Progress 594 of 624 | 540,Jambi City
# Success: Progress 595 of 624 | 541,Ringe
# Success: Progress 596 of 624 | 542,Mariehamn
# Success: Progress 597 of 624 | 543,Philadelphia
# Success: Progress 598 of 624 | 544,Maradi
# Success: Progress 599 of 624 | 545,Panzhihua
# Success: Progress 600 of 624 | 546,Hyères
# Fail: Progress 601 of 625
# Success: Progress 602 of 624 | 547,Shangrao
# Success: Progress 603 of 624 | 548,Batetskiy
# Success: Progress 604 of 624 | 549,Kemijärvi
# Success: Progress 605 of 624 | 550,Shar
# Success: Progress 606 of 624 | 551,Hirtshals
# Success: Progress 607 of 624 | 552,Dingle
# Success: Progress 608 of 624 | 553,Eureka
# Success: Progress 609 of 624 | 554,Maglie
# Success: Progress 610 of 624 | 555,Goma
# Success: Progress 611 of 624 | 556,Holbeach
# Success: Progress 612 of 624 | 557,Sørland
# Success: Progress 613 of 624 | 558,Wad Rāwah
# Success: Progress 614 of 624 | 559,Nanortalik
# Success: Progress 615 of 624 | 560,Aklavik
# Success: Progress 616 of 624 | 561,Luzhou
# Success: Progress 617 of 624 | 562,Purificación
# Success: Progress 618 of 624 | 563,Yangi Marg`ilon
# Success: Progress 619 of 624 | 564,Malbork
# Fail: Progress 620 of 625
# Success: Progress 621 of 624 | 565,Formosa
# Success: Progress 622 of 624 | 566,Eirunepé
# Success: Progress 623 of 624 | 567,Mayachnyy
# Success: Progress 624 of 624 | 568,Shelton

# %%
#pprint.pprint(output)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame.from_dict(weather, orient="index")
city_data.to_csv ((output_data_file), index = True, header=True, index_label="City_ID")
city_data['Date'] = pd.to_datetime(city_data['Date'], unit='s').dt.date
city_data
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0         Ushuaia          40      AR  2022-04-23        75 -54.8000
# 1    San Patricio          33      US  2022-04-23        81  28.0170
# 2      Butaritari          12      KI  2022-04-23        72   3.0707
# 3      Abu Samrah          89      SY  2022-04-23        19  35.3029
# 4       Busselton           0      AU  2022-04-23        59 -33.6500
# ..            ...         ...     ...         ...       ...      ...
# 564       Malbork           7      PL  2022-04-23        91  54.0359
# 565       Formosa         100      AR  2022-04-23        94 -26.1775
# 566      Eirunepé          27      BR  2022-04-23        96  -6.6603
# 567     Mayachnyy          57      RU  2022-04-23        63  52.6839
# 568       Shelton           0      US  2022-04-23        44  41.3165
#
#           Lng  Max Temp  Wind Speed
# 0    -68.3000     42.46        2.30
# 1    -97.5169     77.09       18.25
# 2    172.7902     82.62       19.64
# 3     37.1841     63.50        4.83
# 4    115.3333     63.46       13.62
# ..        ...       ...         ...
# 564   19.0266     41.88        6.51
# 565  -58.1781     69.78        6.91
# 566  -69.8736     73.17        2.37
# 567   55.6850     41.72       10.38
# 568  -73.0932     57.22        9.22
#
# [569 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humid_ind = city_data.loc[city_data['Humidity'] > 100]
humid_ind
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data.loc[city_data['Humidity'] <= 100]
date = clean_city_data.loc[1 , "Date"]
clean_city_data
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0         Ushuaia          40      AR  2022-04-23        75 -54.8000
# 1    San Patricio          33      US  2022-04-23        81  28.0170
# 2      Butaritari          12      KI  2022-04-23        72   3.0707
# 3      Abu Samrah          89      SY  2022-04-23        19  35.3029
# 4       Busselton           0      AU  2022-04-23        59 -33.6500
# ..            ...         ...     ...         ...       ...      ...
# 564       Malbork           7      PL  2022-04-23        91  54.0359
# 565       Formosa         100      AR  2022-04-23        94 -26.1775
# 566      Eirunepé          27      BR  2022-04-23        96  -6.6603
# 567     Mayachnyy          57      RU  2022-04-23        63  52.6839
# 568       Shelton           0      US  2022-04-23        44  41.3165
#
#           Lng  Max Temp  Wind Speed
# 0    -68.3000     42.46        2.30
# 1    -97.5169     77.09       18.25
# 2    172.7902     82.62       19.64
# 3     37.1841     63.50        4.83
# 4    115.3333     63.46       13.62
# ..        ...       ...         ...
# 564   19.0266     41.88        6.51
# 565  -58.1781     69.78        6.91
# 566  -69.8736     73.17        2.37
# 567   55.6850     41.72       10.38
# 568  -73.0932     57.22        9.22
#
# [569 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(clean_city_data["Lat"],clean_city_data["Max Temp"])

plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title(f"Latitude vs. Temperature Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvT.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(clean_city_data["Lat"],clean_city_data["Humidity"])

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Latitude vs. Humidity Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvH.png")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness"])

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Latitude vs. Cloudiness Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvC.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(clean_city_data["Lat"],clean_city_data["Wind Speed"])

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Latitude vs. Wind Speed Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvWS.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Linear Regression

# %%
nor_cit_dat = clean_city_data.loc[clean_city_data['Lat'] > 0]
sou_cit_dat = clean_city_data.loc[clean_city_data['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
nh_mt_lat_slope, nh_mt_lat_int, nh_mt_lat_r, nh_mt_lat_p, nh_mt_lat_std_err = \
    linregress(nor_cit_dat["Lat"],nor_cit_dat["Max Temp"])
nh_mt_lat_line = nh_mt_lat_slope * nor_cit_dat["Lat"] + nh_mt_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(nor_cit_dat["Lat"],nor_cit_dat["Max Temp"])
plt.plot(nor_cit_dat["Lat"],nh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title(f"Southern Hem Latitudes vs Max Temp Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvT_NH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
sh_mt_lat_slope, sh_mt_lat_int, sh_mt_lat_r, sh_mt_lat_p, sh_mt_lat_std_err = \
    linregress(sou_cit_dat["Lat"],sou_cit_dat["Max Temp"])
sh_mt_lat_line = sh_mt_lat_slope * sou_cit_dat["Lat"] + sh_mt_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(sou_cit_dat["Lat"],sou_cit_dat["Max Temp"])
plt.plot(sou_cit_dat["Lat"],sh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title(f"Southern Hem Latitudes vs Max Temp Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvT_SH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
nh_h_lat_slope, nh_h_lat_int, nh_h_lat_r, nh_h_lat_p, nh_h_lat_std_err = \
    linregress(nor_cit_dat["Lat"],nor_cit_dat["Humidity"])
nh_h_lat_line = nh_h_lat_slope * nor_cit_dat["Lat"] + nh_h_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(nor_cit_dat["Lat"],nor_cit_dat["Humidity"])
plt.plot(nor_cit_dat["Lat"],nh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hem Latitudes vs. Humidity (%) Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvH_NH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
sh_h_lat_slope, sh_h_lat_int, sh_h_lat_r, sh_h_lat_p, sh_h_lat_std_err = \
    linregress(sou_cit_dat["Lat"],sou_cit_dat["Humidity"])
sh_h_lat_line = sh_h_lat_slope * sou_cit_dat["Lat"] + sh_h_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(sou_cit_dat["Lat"],sou_cit_dat["Humidity"])
plt.plot(sou_cit_dat["Lat"],sh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hem Latitudes vs. Humidity (%) Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvH_SH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
nh_c_lat_slope, nh_c_lat_int, nh_c_lat_r, nh_c_lat_p, nh_c_lat_std_err = \
    linregress(nor_cit_dat["Lat"],nor_cit_dat["Cloudiness"])
nh_c_lat_line = nh_c_lat_slope * nor_cit_dat["Lat"] + nh_c_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(nor_cit_dat["Lat"],nor_cit_dat["Cloudiness"])
plt.plot(nor_cit_dat["Lat"],nh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Northern Hem Latitudes vs. Cloudiness (%) Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvC_NH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
sh_c_lat_slope, sh_c_lat_int, sh_c_lat_r, sh_c_lat_p, sh_c_lat_std_err = \
    linregress(sou_cit_dat["Lat"],sou_cit_dat["Cloudiness"])
sh_c_lat_line = sh_c_lat_slope * sou_cit_dat["Lat"] + sh_c_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(sou_cit_dat["Lat"],sou_cit_dat["Cloudiness"])
plt.plot(sou_cit_dat["Lat"],sh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Southern Hem Latitudes vs. Cloudiness (%) Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvC_SH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
nh_ws_lat_slope, nh_ws_lat_int, nh_ws_lat_r, nh_ws_lat_p, nh_ws_lat_std_err = \
    linregress(nor_cit_dat["Lat"],nor_cit_dat["Wind Speed"])
nh_ws_lat_line = nh_ws_lat_slope * nor_cit_dat["Lat"] + nh_ws_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(nor_cit_dat["Lat"],nor_cit_dat["Wind Speed"])
plt.plot(nor_cit_dat["Lat"],nh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Northern Hem Latitudes vs. Wind Speed Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvWS_NH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
sh_ws_lat_slope, sh_ws_lat_int, sh_ws_lat_r, sh_ws_lat_p, sh_ws_lat_std_err = \
    linregress(sou_cit_dat["Lat"],sou_cit_dat["Wind Speed"])
sh_ws_lat_line = sh_ws_lat_slope * sou_cit_dat["Lat"] + sh_ws_lat_int

plt.figure(figsize=(10,10))
plt.style.use("ggplot")
plt.scatter(sou_cit_dat["Lat"],sou_cit_dat["Wind Speed"])
plt.plot(sou_cit_dat["Lat"],sh_mt_lat_line,color='#00FFFF',linestyle=":")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Southern Hem Latitudes vs. Wind Speed Plot : {today}")
plt.tight_layout()

plt.savefig("output_data/LvWS_SH.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Observations
## 1: Looking at all plots of Latitude vs Max Temperature, there is a strong correlation showing the closer you are
## to the Equator the hotter it is.
## 2: The plots all relating to both wind speed and cloudiness seem to be random. Just on examination of plots would 
## make it seem there is a very weak correlation on the Equators affects of this two weather measurements.
## 3: Humidity appears to have a possible correlation to closiness to Equator, but this would be mild and feel that
## water near location would also have an affect.
